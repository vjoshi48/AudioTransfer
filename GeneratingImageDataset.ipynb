# %%
# %pip install librosa
# !pip install soxr
# !pip install --upgrade librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pdb import set_trace

# %%
import glob
#file paths to all songs
trap_songs = glob.glob('trap/*')
rock_songs = glob.glob('90_rock/*')

# %%
import scipy
import cv2
import soxr
#generating final trap images for model
#size of image should be below (2500 X 5000)

#parameters for model
n_fft = 2048 #change this (2048, 1024, 512)
hop_length = 512 #change this (the above value // 4)
pre = 0.4

for i in range(len(trap_songs)):
  
  # Load the audio clip from path file
  y, sr = librosa.load(trap_songs[i], sr = 22500, res_type='soxr_vhq') #chage the sr (44100, 22500)

  y = librosa.effects.preemphasis(y, coef = 0.4)

  # Compute the STFT magnitude spectrogram
  stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length, window=scipy.signal.windows.hamming)
  stft_magnitude = np.abs(stft)

  # Save the spectrogram as an image
  image_name = trap_songs[i].split('/')[-1][:-4] + '.png'
  #####NOTE NOTE NOTE
  #make sure to save trap songs and rock songs in different folders
  full_image_name = 'Images/train/trap/' + image_name

  """
  Below lines comment out the code that saves images in order to preserve folder structure and not take up excess memory when this file runs.
  """
  #cv2.imwrite(full_image_name, stft_magnitude)

  # Load the spectrogram image and convert it to a float32 array
  spectrogram = cv2.imread(full_image_name, cv2.IMREAD_GRAYSCALE).astype('float32')

  # Normalize the spectrogram to the range [0, 1]
  spectrogram /= 255.0

  # Reconstruct the audio waveform from the spectrogram
  audio = librosa.griffinlim(spectrogram, hop_length=hop_length, win_length=n_fft)
  #to test audio, check the original audio in the folders and compare it while keeping your computer's audio output to MONO

  file_name = trap_songs[i].split('/')[-1]
  file_name_full = 'audio/' + file_name

  """
  Below lines comment out the writing to audio in order to preserve folder structure and not take up excess memory when this file runs.
  """
  #import soundfile
  #soundfile.write(file_name_full, audio, samplerate=sr)
# Out:
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1307)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1307)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1307)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1316)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1307)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1307)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# (1025, 1318)
# ...

# %%
import cv2
import soxr
import scipy

#generating final rock images for model

#parameters for model
n_fft = 2048
hop_length = 512
pre = 0.4

for i in range(len(rock_songs)):
  
  # Load the audio clip from path file
  y, sr = librosa.load(rock_songs[i], sr = 22500, res_type='soxr_vhq')

  y = librosa.effects.preemphasis(y, coef=0.4)

  # Compute the STFT magnitude spectrogram
  stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length, window=scipy.signal.windows.hamming)
  stft_magnitude = np.abs(stft)

  # Save the spectrogram as an image
  image_name = rock_songs[i].split('/')[-1][:-4] + '.png'
  full_image_name = '/content/drive/MyDrive/DL_Project/DL_Project/images/train/rock/' + image_name

  """
  Below lines comment out the writing to image in order to preserve folder structure and not take up excess memory when this file runs.
  """
  #cv2.imwrite(full_image_name, stft_magnitude)

  # Load the spectrogram image and convert it to a float32 array
  spectrogram = cv2.imread(full_image_name, cv2.IMREAD_GRAYSCALE).astype('float32')

  # Normalize the spectrogram to the range [0, 1]
  spectrogram /= 255.0

  # Reconstruct the audio waveform from the spectrogram
  audio = librosa.griffinlim(spectrogram, hop_length=hop_length, win_length=n_fft)

  file_name = rock_songs[i].split('/')[-1]
  file_name_full = '/content/drive/MyDrive/DL_Project/DL_Project/audio/rock/' + file_name

  """
  Below lines comment out the writing to audio in order to preserve folder structure and not take up excess memory when this file runs.
  """
  
  #import soundfile
  #soundfile.write(file_name_full, audio, samplerate=sr)
